# %% [markdown]
# # Chapter 4 - Practical Data Visualization
# ## Segment 1 - Creating standard data graphics

# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Creating a line chart from a list object

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %%
x = np.arange(1,10,1)
y = [1,2,3,4,3,2,5,2,0]
plt.plot(x,y)

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
address = 'C:/Users/hp/Downloads/python data science screenshot/Ex_Files_Python_Data_Science_EssT_Pt_1/Ex_Files_Python_Data_Science_EssT_Pt_1/Exercise Files/Data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars['mpg']
cyl = cars['cyl']

# %%
mpg,cyl
# Out:
# (0     21.0
#  1     21.0
#  2     22.8
#  3     21.4
#  4     18.7
#  5     18.1
#  6     14.3
#  7     24.4
#  8     22.8
#  9     19.2
#  10    17.8
#  11    16.4
#  12    17.3
#  13    15.2
#  14    10.4
#  15    10.4
#  16    14.7
#  17    32.4
#  18    30.4
#  19    33.9
#  20    21.5
#  21    15.5
#  22    15.2
#  23    13.3
#  24    19.2
#  25    27.3
#  26    26.0
#  27    30.4
#  28    15.8
#  29    19.7
#  30    15.0
#  31    21.4
#  Name: mpg, dtype: float64,
#  0     6
#  1     6
#  2     4
#  3     6
#  4     8
#  5     6
#  6     8
#  7     4
#  8     4
#  9     6
#  10    6
#  11    8
#  12    8
#  13    8
#  14    8
#  15    8
#  16    8
#  17    4
#  18    4
#  19    4
#  20    4
#  21    8
#  22    8
#  23    8
#  24    8
#  25    4
#  26    4
#  27    4
#  28    8
#  29    6
#  30    8
#  31    4
#  Name: cyl, dtype: int64)

# %%
mpg.plot()
cyl.plot()
# Out:
# <AxesSubplot:>

# %%
data = cars[['cyl','wt','mpg']]
data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
mpg.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
mpg.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='mpg'>

# %%
mpg.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating a pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x28e2fc52ac0>,
#   <matplotlib.patches.Wedge at 0x28e2fc52fa0>,
#   <matplotlib.patches.Wedge at 0x28e2fc61460>,
#   <matplotlib.patches.Wedge at 0x28e2fc617c0>,
#   <matplotlib.patches.Wedge at 0x28e2fc61c40>],
#  [Text(1.0511300845578104, 0.32423069770996493, ''),
#   Text(0.4018751039768062, 1.0239611324672588, ''),
#   Text(-0.9910657898026471, 0.47727204012266977, ''),
#   Text(0.0822032521067005, -1.096924165721169, ''),
#   Text(1.0877139352529008, -0.1639463176062465, '')])

# %% [markdown]
# ### Saving a plot

# %%
plt.pie(x)
plt.savefig('pie_chart.png')
